# %%
# a = int(input())
# b = int(input())
# m = (a * b)
# print(m)

# %%
# print("1. Mix")
# print("2. Kned")
# print("3. Add")
# print("4. Leave")
# print("5. Bake")

# %%
# print("He came"then"he left")
# print('He came "then" he left')
# print("He came \"then\" he left")

# %%
# print("A 'single quote' inside double quote")
# print('A "double quote" inside a single quote')
# print("Alternatively I can just \"escape\" the quote")

# %%
# print("Rohan\nYadav")
# print("I am" + " rohan.")

# %%
#fixing the code:
print("Day 1: String manupulation")
print("String Concatenation is done with the \"+\" sign.")
print('e.g. print("hello " + "world")')
print("New lines can be created with a backslash and n.")
# Out:
# Day 1: String manupulation
# String Concatenation is done with the "+" sign.
# e.g. print("hello " + "world")
# New lines can be created with a backslash and n.

# %%
print("Hi " + input("Who are you?"))
# Out:
# Who are you?Man.
# Hi Man.

# %%
numberOfLetters = len("Rohan")
print(numberOfLetters)
# Out:
# 5

# %%
print(len(input()))
# Out:
# Row
# 3

# %%
#print(len(input("Insert your name: ")))

name = input("Insert your name: ")
length = len(name)
print(length)
# Out:
# Insert your name: Rohan
# 5

# %%
a = input()
b = input()

t = a
a = b
b = t


print("a : " + a)
print("b : " + b)
# Out:
# 10
# 20
# a : 20
# b : 10

# %%
print("Welcome to the brand name generator.")
print("What is the name of city you grew up in?")
city = input()
print("What is your pet's name?")
pet = input()
print("Your brand name could be: " + city + " " + pet)
# Out:
# Welcome to the brand name generator.
# What is the name of city you grew up in?
# Andal
# What is your pet's name?
# Paltu
# Your brand name could be: Andal Paltu
