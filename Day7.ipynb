# %%
#HANGMAN
import random
#Step 1:
word_list = ["ardvark", "baboon", "camel"]

#todo 1 : randomly choose a word and store in chosen_word
# chosen_word = word_list[random.randint(0, len(word_list) - 1)]
chosen_word = random.choice(word_list)
print(chosen_word)

#todo 2 : ask the user to guess a letter and assign their answer to guess
guess = input("Guess a letter: ").lower()

#todo 3: check if the letter of the guess is one of the letter of chosen word
for letter in chosen_word:
    if(guess == letter):
        print("right")
    else:
        print("wrong")
# Out:
# camel
# Guess a letter: a
# wrong
# right
# wrong
# wrong
# wrong

# %%
#HANGMAN
import random
#Step 2:
word_list = ["ardvark", "baboon", "camel"]

chosen_word = random.choice(word_list)

#testing code
print(f"pssst, the solution is {chosen_word}.")
#todo 1: create an empty list called display, for each letter in chosen word add _ to display
display = []

for _ in range(len(chosen_word)):
    display.append("_")
# print(display)


guess = input("Guess a letter: ").lower()
#todo 2: loop through each position of the chosen_word;
#if the letter at the position matches 'guess' then reveal the letter in the display at the

# for index in range(len(chosen_word)):
#     if guess == chosen_word[index]:
#         display[index] = guess
# print(display)

for index, letter in enumerate(chosen_word):
    if(guess == letter):
        display[index] = guess
print(display)
# Out:
# pssst, the solution is baboon.
# Guess a letter: a
# ['_', 'a', '_', '_', '_', '_']

# %%
#HANGMAN
import random
#Step 3:
word_list = ["ardvark", "baboon", "camel"]

chosen_word = random.choice(word_list)


print(f"pssst, the solution is {chosen_word}.")
display = []
for _ in range(len(chosen_word)):
    display.append("_")
#todo 1: use a while loop to let the user guess again. The loop should only stop once the user has guessed all the letters in the chosen_word and display has no more _. then tell them that they've won

blanks = display.count("_")

lives = 3

while(blanks != 0 and lives != 0):
    guess = input("Guess a letter: ").lower()
    if guess in display:
        print(f"You already guessed {guess}. Try another letter.")
        continue
    found = False
    for index, letter in enumerate(chosen_word):
        if(guess == letter):
            display[index] = guess
            blanks -= 1
            found = True
    if not found:
        lives -= 1
    print(display)
    if(blanks == 0):
        print("You won.")
    elif(lives == 0):
        print("You lost.")
# Out:
# pssst, the solution is baboon.
# Guess a letter: b
# ['b', '_', 'b', '_', '_', '_']
# Guess a letter: b
# You already guessed b. Try another letter.
# Guess a letter: b
# You already guessed b. Try another letter.
# Guess a letter: b
# You already guessed b. Try another letter.
# Guess a letter: b
# You already guessed b. Try another letter.
# Guess a letter: a
# ['b', 'a', 'b', '_', '_', '_']
# Guess a letter: o
# ['b', 'a', 'b', 'o', 'o', '_']
# Guess a letter: n
# ['b', 'a', 'b', 'o', 'o', 'n']
# You won.

# %%
import random
from hangman_wordlist import  word_list
logo = r""" _
| |
| |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
| '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
| | | | (_| | | | | (_| | | | | | | (_| | | | |
|_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
                    __/ |
                   |___/
"""
print(logo)
stages = [r'''
  +---+
  |   |
      |
      |
      |
      |
=========
''', r'''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', r'''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', r'''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========
''', r'''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', r'''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', r'''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''']




chosen_word = random.choice(word_list)
# print(f"pssst, the solution is {chosen_word}.")
display = []
for _ in range(len(chosen_word)):
    display.append("_")

lives = 6

while "_" in display and lives > 0:
    guess = input("Guess a letter: ").lower()
    if guess in display:
        print(f"You already guessed {guess}. Try another letter.")
        continue
    found = False
    for index, letter in enumerate(chosen_word):
        if guess == letter and display[index] == "_":
            display[index] = guess
            found = True
    if not found:
        lives -= 1
    print(stages[6 - lives])
    print(" ".join(display))
    if "_" not in display:
        print("You won.")
    elif lives == 0:
        print("You lost.")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\ '
# <>:6: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-3405707749.py:6: SyntaxWarning: invalid escape sequence '\ '
#   | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
#
# pssst, the solution is koala.
# Guess a letter: k
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# k _ _ _ _
# Guess a letter: o
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# k o _ _ _
# Guess a letter: a
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# k o a _ a
# Guess a letter: l
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# k o a l a
# You won.
